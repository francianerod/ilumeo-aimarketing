# %% [markdown]
# # **TESTE OFICIAL - Parte 1 - Organização dos dados**

# %%
# Abertura de biblioteca
import pandas as pd
import numpy as np
import re

# 1. Configurações Iniciais
pd.set_option('display.max_columns', 500)
file_path = '/content/BASE-ONDA-PROCESSADA--72353 - Copia.xlsx'

# %%
def carregar_e_padronizar_dados(path):
    try:
        # Lê considerando as duas primeiras linhas como cabeçalho
        df = pd.read_excel(path, header=[0, 1])

        # Função interna para unificar cabeçalhos
        def clean_header(col):
            question, option = col
            # Se a opção for "Unnamed" (vazia) ou inexistente, usa só a pergunta
            if "Unnamed" in str(option) or not str(option):
                return str(question).strip()
            # Se a pergunta for "Unnamed" (repetida/mesclada), usa só a opção
            if "Unnamed" in str(question):
                return str(option).strip()
            # Padrão: Pergunta - Opção
            return f"{str(question).strip()} - {str(option).strip()}"

        # Aplica a unificação dos nomes
        df.columns = [clean_header(col) for col in df.columns]
        print("✅ Arquivo carregado e cabeçalhos unificados com sucesso.")
        return df

    except Exception as e:
        print(f"❌ Erro ao processar arquivo: {e}")
        return None

# %%
def filtrar_respondentes_validos(df):
    # Nome exato da coluna após a unificação dos cabeçalhos
    # Verifique se o nome gerado pelo clean_header bate com este abaixo
    coluna_filtro = 'RESPOSTA ESTÁ DENTRO DA PROPORCIONALIZAÇÃO? - imported_in_delfos'

    if coluna_filtro in df.columns:
        linhas_iniciais = df.shape[0]
        # Mantém apenas quem NÃO é 'NÃO' (ou seja, mantém os válidos)
        df = df[df[coluna_filtro] != 'NÃO']
        removidos = linhas_iniciais - df.shape[0]
        print(f"✅ Filtragem de linhas: {removidos} respondentes removidos (Status 'NÃO'). Totalizando amostragem: ", df.shape[0])
    else:
        print(f"⚠️ Coluna de filtro '{coluna_filtro}' não encontrada. Nenhuma linha removida.")

    return df

# %%
def limpar_colunas_indesejadas(df):
    termos_proibidos = [
        # 1. Metadados do Sistema
        'RESPOSTA ESTÁ DENTRO DA PROPORCIONALIZAÇÃO? - imported_in_delfos',
        'user_invitation_code - user_invitation_code',
        'collector_id - collector_id',
        'date_modified - date_modified',
        'ip_address - ip_address',
        'status - status',
        'total_time - total_time',
        'complement_status - complement_status',
        'Você estuda ou trabalha em uma dessas atividades? #prof - Response',
        'Você estuda ou trabalha em uma dessas atividades? #prof - Outro (especifique)',

        # 2. Tags de Funil e Processamento
        '#aberta_en',
        '#awesp',     # Awareness Espontâneo
        '#aberta_op', # Perguntas abertas gerais
        '#faw',       # Funnel Awareness (Ouviu falar)
        '#fkn',       # Funnel Known (Conhece bem)
        '#flk',       # Funnel Like (Gosta)
        '#fco',       # Funnel Consideration (Consideração)
        '#fpr',       # Funnel Preference
        '#clt',       # Client (É cliente)
        '#rej',       # Rejection (Rejeição)
        '#mar',       # Marca avaliada (se quiser remover todas as colunas dessa tag)

        # 3. Perguntas de Associação/Lixo
        'PRIMEIRA PALAVRA',
        '{{',
        "PRÓXIMA COMPRA",
        'Você gostou de responder essa pesquisa? - Response'
                        ]

    colunas_para_remover = []

    # Correção da sintaxe do loop aqui
    for coluna in df.columns:
        for termo in termos_proibidos:
            if termo in coluna:
                colunas_para_remover.append(coluna)
                break

    n_antes = df.shape[1]
    df_limpo = df.drop(columns=colunas_para_remover, errors='ignore')
    n_depois = df_limpo.shape[1]

    print(f"✅ Limpeza de colunas: {n_antes - n_depois} colunas removidas.")
    print(f"📊 Shape final do dataset: {df_limpo.shape}")

    return df_limpo

# %%
# --- EXECUÇÃO DO PIPELINE ---

# 1. Carregar
df = carregar_e_padronizar_dados(file_path)

if df is not None:
    # 2. Filtrar Linhas (IMPORTANTE: Fazer isso antes de remover a coluna de controle)
    df = filtrar_respondentes_validos(df)

    # 3. Limpar Colunas
    df = limpar_colunas_indesejadas(df)

# %%
# 4. Mostrar tabela
#df.head(1)

# 5. Mostrar colunas disponiveis
#df.columns.tolist()

# %% [markdown]
# # **SCRIPT OFICIAL - PARTE 1**

# %%
# Abertura de biblioteca
import pandas as pd
import numpy as np
import re

# 1. Configurações Iniciais
pd.set_option('display.max_columns', 500)
file_path = '/content/BASE-ONDA-PROCESSADA--72353 - Copia.xlsx'

def carregar_e_padronizar_dados(path):
    try:
        # Lê considerando as duas primeiras linhas como cabeçalho
        df = pd.read_excel(path, header=[0, 1])

        # Função interna para unificar cabeçalhos
        def clean_header(col):
            question, option = col
            # Se a opção for "Unnamed" (vazia) ou inexistente, usa só a pergunta
            if "Unnamed" in str(option) or not str(option):
                return str(question).strip()
            # Se a pergunta for "Unnamed" (repetida/mesclada), usa só a opção
            if "Unnamed" in str(question):
                return str(option).strip()
            # Padrão: Pergunta - Opção
            return f"{str(question).strip()} - {str(option).strip()}"

        # Aplica a unificação dos nomes
        df.columns = [clean_header(col) for col in df.columns]
        print("✅ Arquivo carregado e cabeçalhos unificados com sucesso.")
        return df

    except Exception as e:
        print(f"❌ Erro ao processar arquivo: {e}")
        return None

def filtrar_respondentes_validos(df):
    # Nome exato da coluna após a unificação dos cabeçalhos
    # Verifique se o nome gerado pelo clean_header bate com este abaixo
    coluna_filtro = 'RESPOSTA ESTÁ DENTRO DA PROPORCIONALIZAÇÃO? - imported_in_delfos'

    if coluna_filtro in df.columns:
        linhas_iniciais = df.shape[0]
        # Mantém apenas quem NÃO é 'NÃO' (ou seja, mantém os válidos)
        df = df[df[coluna_filtro] != 'NÃO']
        removidos = linhas_iniciais - df.shape[0]
        print(f"✅ Filtragem de linhas: {removidos} respondentes removidos (Status 'NÃO'). Totalizando amostragem: ", df.shape[0])
    else:
        print(f"⚠️ Coluna de filtro '{coluna_filtro}' não encontrada. Nenhuma linha removida.")

    return df

def limpar_colunas_indesejadas(df):
    termos_proibidos = [
        # 1. Metadados do Sistema
        'RESPOSTA ESTÁ DENTRO DA PROPORCIONALIZAÇÃO? - imported_in_delfos',
        'user_invitation_code - user_invitation_code',
        'collector_id - collector_id',
        'date_modified - date_modified',
        'ip_address - ip_address',
        'status - status',
        'total_time - total_time',
        'complement_status - complement_status',
        'Você estuda ou trabalha em uma dessas atividades? #prof - Response',
        'Você estuda ou trabalha em uma dessas atividades? #prof - Outro (especifique)',

        # 2. Tags de Funil e Processamento
        '#aberta_en',
        '#awesp',     # Awareness Espontâneo
        '#aberta_op', # Perguntas abertas gerais
        '#faw',       # Funnel Awareness (Ouviu falar)
        '#fkn',       # Funnel Known (Conhece bem)
        '#flk',       # Funnel Like (Gosta)
        '#fco',       # Funnel Consideration (Consideração)
        '#fpr',       # Funnel Preference
        '#clt',       # Client (É cliente)
        '#rej',       # Rejection (Rejeição)
        '#mar',       # Marca avaliada (se quiser remover todas as colunas dessa tag)

        # 3. Perguntas de Associação/Lixo
        'PRIMEIRA PALAVRA',
        '{{',
        "PRÓXIMA COMPRA",
        'Você gostou de responder essa pesquisa? - Response'
    ]

    colunas_para_remover = []

    # Correção da sintaxe do loop aqui
    for coluna in df.columns:
        for termo in termos_proibidos:
            if termo in coluna:
                colunas_para_remover.append(coluna)
                break

    n_antes = df.shape[1]
    df_limpo = df.drop(columns=colunas_para_remover, errors='ignore')
    n_depois = df_limpo.shape[1]

    print(f"✅ Limpeza de colunas: {n_antes - n_depois} colunas removidas.")
    print(f"📊 Shape final do dataset: {df_limpo.shape}")

    return df_limpo

# --- EXECUÇÃO DO PIPELINE ---

# 1. Carregar
df = carregar_e_padronizar_dados(file_path)

if df is not None:
    # 2. Filtrar Linhas (IMPORTANTE: Fazer isso antes de remover a coluna de controle)
    df = filtrar_respondentes_validos(df)

    # 3. Limpar Colunas
    df = limpar_colunas_indesejadas(df)
# Out:
# ✅ Arquivo carregado e cabeçalhos unificados com sucesso.
# ✅ Filtragem de linhas: 65 respondentes removidos (Status 'NÃO'). Totalizando amostragem:  400
# ✅ Limpeza de colunas: 197 colunas removidas.
# 📊 Shape final do dataset: (400, 162)

# %% [markdown]
# # **TESTE OFICIAL - Parte 2 - Limpeza dos Dados**

# %%
df["Em qual cidade você mora? #cid - Response"] = df["Em qual cidade você mora? #cid - Response"].replace("", np.nan)
df["Em qual cidade você mora? #cid - Response"] = df["Em qual cidade você mora? #cid - Response"].fillna(df["Em qual cidade você mora? #cid - Outro (especifique)"])
df["Qual é o seu gênero ? #gen - Response"] = df["Qual é o seu gênero ? #gen - Response"].replace("", np.nan)
df["Qual é o seu gênero ? #gen - Response"] = df["Qual é o seu gênero ? #gen - Response"].fillna(df["Qual é o seu gênero ? #gen - Outro (especifique)"])

# %%
df = df.drop(columns=["Em qual cidade você mora? #cid - Outro (especifique)",
                      "Qual é o seu gênero ? #gen - Outro (especifique)"
                     ])

# %%
import re

def remove_html(text):
    if pd.isna(text):
        return text
    # remove qualquer tag HTML
    return re.sub(r"<.*?>", "", str(text)).strip()

df = df.applymap(remove_html)

# %%
# 1. Definição da função (fornecida por você, inclusa aqui para o contexto)
def limpar_likert(valor):
    if pd.isna(valor):
        return np.nan

    valor_str = str(valor).strip()

    # CASO 0 ou 10 venham com texto
    if valor_str.startswith("0"):
        return 0
    if valor_str.startswith("10"):
        return 10

    # CASO 1–9 já sejam limpos
    if valor_str.isdigit():
        return int(valor_str)

    # Se nada funcionar → NA
    return np.nan

# 2. Identifica as colunas que possuem escalas de nota 0-10
colunas_escala = [
    col for col in df.columns
    if "gostaria de" in col.lower()
    or "receber como presente" in col.lower()
    or "nota" in col.lower()
]

# 3. Aplica a função a cada coluna identificada
print(f"🔄 Aplicando limpeza Likert em {len(colunas_escala)} colunas...")

for col in colunas_escala:
    # O método .apply() executa a função 'limpar_likert' em cada célula da coluna
    df[col] = df[col].apply(limpar_likert)

    # Garante que o tipo final seja float, para que você possa calcular a média (média ponderada)
    df[col] = pd.to_numeric(df[col], errors='coerce')

print("✅ Limpeza de escalas Likert concluída.")

# %%
df["Em qual cidade você mora? #cid - Response"] = df["Em qual cidade você mora? #cid - Response"].replace("", np.nan)
df["Em qual cidade você mora? #cid - Response"] = df["Em qual cidade você mora? #cid - Response"].fillna(df["Em qual cidade você mora? #cid - Outro (especifique)"])
df["Qual é o seu gênero ? #gen - Response"] = df["Qual é o seu gênero ? #gen - Response"].replace("", np.nan)
df["Qual é o seu gênero ? #gen - Response"] = df["Qual é o seu gênero ? #gen - Response"].fillna(df["Qual é o seu gênero ? #gen - Outro (especifique)"])

df = df.drop(columns=[
    "Em qual cidade você mora? #cid - Outro (especifique)",
    "Qual é o seu gênero ? #gen - Outro (especifique)"
])

import re

def remove_html(text):
    if pd.isna(text):
        return text
    # remove qualquer tag HTML
    return re.sub(r"<.*?>", "", str(text)).strip()

df = df.applymap(remove_html)

# 1. Definição da função (fornecida por você)
def limpar_likert(valor):
    if pd.isna(valor):
        return np.nan

    valor_str = str(valor).strip()

    # CASO 0 ou 10 venham com texto
    if valor_str.startswith("0"):
        return 0
    if valor_str.startswith("10"):
        return 10

    # CASO 1–9 já sejam limpos
    if valor_str.isdigit():
        return int(valor_str)

    # Se nada funcionar → NA
    return np.nan

# 2. Identifica as colunas que possuem escalas de nota 0-10
colunas_escala = [
    col for col in df.columns
    if "gostaria de" in col.lower()
    or "receber como presente" in col.lower()
    or "nota" in col.lower()
]

# 3. Aplica a função a cada coluna identificada
print(f"🔄 Aplicando limpeza Likert em {len(colunas_escala)} colunas...")

for col in colunas_escala:
    df[col] = df[col].apply(limpar_likert)
    df[col] = pd.to_numeric(df[col], errors='coerce')  # garante tipo float

print("✅ Limpeza de escalas Likert concluída.")

# %% [markdown]
# # **Script oficial - Parte 2**

# %%
import pandas as pd
import numpy as np
import re

# ============================================================
# 1) AJUSTE DE CIDADE E GÊNERO
# ============================================================

df["Em qual cidade você mora? #cid - Response"] = df["Em qual cidade você mora? #cid - Response"].replace("", np.nan)
df["Em qual cidade você mora? #cid - Response"] = df["Em qual cidade você mora? #cid - Response"].fillna(
    df["Em qual cidade você mora? #cid - Outro (especifique)"]
)

df["Qual é o seu gênero ? #gen - Response"] = df["Qual é o seu gênero ? #gen - Response"].replace("", np.nan)
df["Qual é o seu gênero ? #gen - Response"] = df["Qual é o seu gênero ? #gen - Response"].fillna(
    df["Qual é o seu gênero ? #gen - Outro (especifique)"]
)

df = df.drop(columns=[
    "Em qual cidade você mora? #cid - Outro (especifique)",
    "Qual é o seu gênero ? #gen - Outro (especifique)"
])


# ============================================================
# 2) REMOÇÃO DE HTML
# ============================================================

def remove_html(text):
    if pd.isna(text):
        return text
    return re.sub(r"<.*?>", "", str(text)).strip()

#df = df.applymap(remove_html)
df = df.apply(lambda col: col.map(remove_html) if col.dtype == "object" else col)



# ============================================================
# 3) FUNÇÃO LIMPAR ESCALA LIKERT
# ============================================================

def limpar_likert(valor):
    if pd.isna(valor):
        return np.nan

    valor_str = str(valor).strip()

    if valor_str.startswith("0"):
        return 0
    if valor_str.startswith("10"):
        return 10

    if valor_str.isdigit():
        return int(valor_str)

    return np.nan


# ============================================================
# 4) IDENTIFICAR TODAS AS COLUNAS DE NOTA
# ============================================================

colunas_escala = [
    col for col in df.columns
    if "gostaria de" in col.lower()
    or "receber como presente" in col.lower()
    or "nota" in col.lower()
]

print(f"🔄 Aplicando limpeza Likert em {len(colunas_escala)} colunas...")


# ============================================================
# 5) APLICAR LIMPEZA NAS COLUNAS DE ESCALA
# ============================================================

for col in colunas_escala:
    df[col] = df[col].apply(limpar_likert)
    df[col] = pd.to_numeric(df[col], errors="coerce")
print("✅ Limpeza de escalas Likert concluída.")
# Out:
# 🔄 Aplicando limpeza Likert em 30 colunas...
# ✅ Limpeza de escalas Likert concluída.

# %% [markdown]
# # **TESTE OFICIAL - Parte 3 - Análise de Frequencias**

# %%
import json

def gerar_json_todas_as_tabelas(t_simples, t_multi, t_matriz, t_nota):

    resultado = {
        "perguntas_simples": [],
        "multirresposta": [],
        "matriz_texto": [],
        "matriz_nota": []
    }

    # ============================
    # 1) PERGUNTAS SIMPLES
    # ============================
    for pergunta, tabela in t_simples.items():
        resultado["perguntas_simples"].append({
            "pergunta": pergunta,
            "tabela": tabela.reset_index().rename(columns={"index": "Resposta"}).to_dict(orient="records")
        })

    # ============================
    # 2) MULTIRRESPOSTA
    # ============================
    for pergunta, tabela in t_multi.items():

        bloco = {
            "pergunta": pergunta,
            "marcas": []
        }

        for marca, row in tabela.iterrows():
            bloco["marcas"].append({
                "marca": marca,
                "frequencia_absoluta": int(row["Frequência Absoluta"]),
                "frequencia_relativa": float(row["Frequência Relativa (%)"])
            })

        resultado["multirresposta"].append(bloco)

    # ============================
    # 3) MATRIZ TEXTO
    # ============================
    for pergunta, meios in t_matriz.items():

        bloco = {
            "pergunta": pergunta,
            "itens": []
        }

        for meio, tabela in meios.items():
            bloco["itens"].append({
                "item": meio,
                "tabela": tabela.reset_index().rename(columns={"index": "Resposta"}).to_dict(orient="records")
            })

        resultado["matriz_texto"].append(bloco)

    # ============================
    # 4) MATRIZ NOTA
    # ============================
    for pergunta, marcas in t_nota.items():

        bloco = {
            "pergunta": pergunta,
            "marcas": []
        }

        for marca, tabela in marcas.items():
            bloco["marcas"].append({
                "marca": marca,
                "tabela": tabela.reset_index().rename(columns={"index": "Nota"}).to_dict(orient="records")
            })

        resultado["matriz_nota"].append(bloco)

    return json.dumps(resultado, ensure_ascii=False, indent=2)

# %%
print("\n\n############################################################")
print("######################  RESULTADOS  ########################")
print("############################################################\n\n")


# ============================================================
# 1) PERGUNTAS SIMPLES
# ============================================================
print("\n========================================================")
print("===============  PERGUNTAS SIMPLES  ====================")
print("========================================================\n")

for pergunta, tabela in t_simples.items():
    print("\n--------------------------------------------------------")
    print("PERGUNTA:", pergunta)
    print("--------------------------------------------------------")
    print(tabela)
    print("\n")


# ============================================================
# 2) MULTIRRESPOSTA
# ============================================================
print("\n========================================================")
print("=================  MULTIRRESPOSTA  =====================")
print("========================================================\n")

for pergunta, tabela in t_multi.items():
    print("\n--------------------------------------------------------")
    print("PERGUNTA:", pergunta)
    print("--------------------------------------------------------")
    print(tabela)
    print("\n")


# ============================================================
# 3) MATRIZ TEXTO (ESCALA)
# ============================================================
print("\n========================================================")
print("==================  MATRIZ TEXTO  =======================")
print("========================================================\n")

for pergunta, meios in t_matriz.items():
    print("\n--------------------------------------------------------")
    print("PERGUNTA:", pergunta)
    print("--------------------------------------------------------")

    for meio, tabela in meios.items():
        print(f"\n--- {meio} ---")
        print(tabela)
        print("\n")


# ============================================================
# 4) MATRIZ NOTA (0–10)
# ============================================================
print("\n========================================================")
print("===================  MATRIZ NOTA  =======================")
print("========================================================\n")

for pergunta, marcas in t_nota.items():
    print("\n--------------------------------------------------------")
    print("PERGUNTA:", pergunta)
    print("--------------------------------------------------------")

    for marca, tabela in marcas.items():
        print(f"\n--- {marca} ---")
        print(tabela)
        print("\n")
# Out:
# ############################################################
# ######################  RESULTADOS  ########################
# ############################################################
#
#
#
# ========================================================
# ===============  PERGUNTAS SIMPLES  ====================
# ========================================================
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-547608354.py in <cell line: 0>()
#      11 print("========================================================\n")
#      12
# ---> 13 for pergunta, tabela in t_simples.items():
#      14     print("\n--------------------------------------------------------")
#      15     print("PERGUNTA:", pergunta)
#
# NameError: name 't_simples' is not defined

# %%
json_final = gerar_json_todas_as_tabelas(t_simples, t_multi, t_matriz, t_nota)
print(json_final)

# %% [markdown]
# # **Script Oficial - Parte 3**

# %%
import json
import pandas as pd
from collections import defaultdict

def gerar_json_todas_as_tabelas(t_simples, t_multi, t_matriz, t_nota):

    resultado = {
        "perguntas_simples": [],
        "multirresposta": [],
        "matriz_texto": [],
        "matriz_nota": []
    }

    # ============================
    # 1) PERGUNTAS SIMPLES
    # ============================
    for pergunta, tabela in t_simples.items():
        resultado["perguntas_simples"].append({
            "pergunta": pergunta,
            "tabela": tabela.reset_index().rename(columns={"index": "Resposta"}).to_dict(orient="records")
        })

    # ============================
    # 2) MULTIRRESPOSTA
    # ============================
    for pergunta, tabela in t_multi.items():

        bloco = {
            "pergunta": pergunta,
            "marcas": []
        }

        for marca, row in tabela.iterrows():
            bloco["marcas"].append({
                "marca": marca,
                "frequencia_absoluta": int(row["Frequência Absoluta"]),
                "frequencia_relativa": float(row["Frequência Relativa (%)"])
            })

        resultado["multirresposta"].append(bloco)

    # ============================
    # 3) MATRIZ TEXTO
    # ============================
    for pergunta, meios in t_matriz.items():

        bloco = {
            "pergunta": pergunta,
            "itens": []
        }

        for meio, tabela in meios.items():
            bloco["itens"].append({
                "item": meio,
                "tabela": tabela.reset_index().rename(columns={"index": "Resposta"}).to_dict(orient="records")
            })

        resultado["matriz_texto"].append(bloco)

    # ============================
    # 4) MATRIZ NOTA
    # ============================
    for pergunta, marcas in t_nota.items():

        bloco = {
            "pergunta": pergunta,
            "marcas": []
        }

        for marca, tabela in marcas.items():  # <<–– AQUI FOI CORRIGIDO
            bloco["marcas"].append({
                "marca": marca,
                "tabela": tabela.reset_index().rename(columns={"index": "Nota"}).to_dict(orient="records")
            })

        resultado["matriz_nota"].append(bloco)

    return json.dumps(resultado, ensure_ascii=False, indent=2)


# ============================================================
# FUNÇÕES AUXILIARES PARA GERAÇÃO DAS TABELAS DE FREQUÊNCIA
# ============================================================

def identificar_colunas_simples(df):
    col_response = [col for col in df.columns if "response" in col.lower()]
    col_not_multi = [col for col in df.columns if " - " not in col]
    numericas = df.select_dtypes(include=["int", "float"]).columns.tolist()
    colunas_simples = list(set(col_response + col_not_multi))
    colunas_simples = [c for c in colunas_simples if c not in numericas]
    return colunas_simples

def encontrar_colunas_hifen(df):
    col_hifen = [col for col in df.columns if " - " in col]
    col_sem_response = [col for col in col_hifen if "response" not in col.lower()]
    return list(set(col_sem_response))

def agrupar_por_pergunta(colunas):
    grupos = defaultdict(list)
    for col in colunas:
        pergunta = col.split(" - ")[0].strip()
        grupos[pergunta].append(col)
    return grupos

def classificar_perguntas(df, grupos):
    grupos_multi = {}
    grupos_matriz_texto = {}
    grupos_matriz_nota = {}
    for pergunta, colunas in grupos.items():
        col_exemplo = colunas[0]
        serie = df[col_exemplo].dropna()
        if pd.api.types.is_numeric_dtype(serie):
            grupos_matriz_nota[pergunta] = colunas
            continue
        marca_exemplo = col_exemplo.split(" - ")[1].strip()
        valores = serie.astype(str).str.strip().unique()
        if marca_exemplo in valores:
            grupos_multi[pergunta] = colunas
        else:
            grupos_matriz_texto[pergunta] = colunas
    return grupos_multi, grupos_matriz_texto, grupos_matriz_nota

def tabelas_simples(df, colunas):
    tabelas = {}
    for col in colunas:
        freq_abs = df[col].value_counts(dropna=False)
        freq_rel = df[col].value_counts(normalize=True, dropna=False) * 100
        tabelas[col] = pd.DataFrame({
            "Frequência Absoluta": freq_abs,
            "Frequência Relativa (%)": freq_rel.round(1)
        })
    return tabelas

def tabelas_multiresposta(df, grupos_multi):
    tabelas = {}
    total = len(df)
    for pergunta, colunas in grupos_multi.items():
        marcas = []
        abs_list = []
        rel_list = []
        for col in colunas:
            marca = col.split(" - ")[1].strip()
            freq_abs = (df[col] == marca).sum()
            freq_rel = (freq_abs / total * 100) if total else 0
            marcas.append(marca)
            abs_list.append(freq_abs)
            rel_list.append(round(freq_rel, 1))
        tabelas[pergunta] = pd.DataFrame({
            "Frequência Absoluta": abs_list,
            "Frequência Relativa (%)": rel_list
        }, index=marcas)
    return tabelas

def tabelas_matriz_texto(df, grupos_matriz):
    tabelas = {}
    for pergunta, colunas in grupos_matriz.items():
        meios = {}
        for col in colunas:
            meio = col.split(" - ")[1].strip()
            serie = df[col].dropna().astype(str).str.strip()
            freq_abs = serie.value_counts()
            freq_rel = (serie.value_counts(normalize=True) * 100).round(1)
            meios[meio] = pd.DataFrame({
                "Frequência Absoluta": freq_abs,
                "Frequência Relativa (%)": freq_rel
            })
        tabelas[pergunta] = meios
    return tabelas

def tabelas_matriz_nota(df, grupos_matriz_nota):
    tabelas = {}
    for pergunta, colunas in grupos_matriz_nota.items():
        marcas_dict = {}
        for col in colunas:
            marca = col.split(" - ")[1].strip()
            serie = df[col].dropna()
            freq_abs = serie.value_counts().sort_index()
            freq_rel = (serie.value_counts(normalize=True).sort_index() * 100).round(1)
            marcas_dict[marca] = pd.DataFrame({
                "Frequência Absoluta": freq_abs,
                "Frequência Relativa (%)": freq_rel
            })
        tabelas[pergunta] = marcas_dict
    return tabelas

def gerar_todas_as_tabelas(df):
    col_simples = identificar_colunas_simples(df)
    t_simples = tabelas_simples(df, col_simples)
    col_hifen = encontrar_colunas_hifen(df)
    grupos = agrupar_por_pergunta(col_hifen)
    grupos_multi, grupos_matriz_texto, grupos_matriz_nota = classificar_perguntas(df, grupos)
    t_multi = tabelas_multiresposta(df, grupos_multi)
    t_matriz = tabelas_matriz_texto(df, grupos_matriz_texto)
    t_nota = tabelas_matriz_nota(df, grupos_matriz_nota)
    return t_simples, t_multi, t_matriz, t_nota


# ============================================================
# EXECUÇÃO E IMPRESSÃO DOS RESULTADOS
# ============================================================

# Chamar a função principal para gerar as tabelas
t_simples, t_multi, t_matriz, t_nota = gerar_todas_as_tabelas(df)

print("\n\n############################################################")
print("######################  RESULTADOS  ########################")
print("############################################################\n\n")


# ============================================================
# 1) PERGUNTAS SIMPLES
# ============================================================
print("\n========================================================")
print("===============  PERGUNTAS SIMPLES  ====================")
print("========================================================\n")

for pergunta, tabela in t_simples.items():
    print("\n--------------------------------------------------------")
    print("PERGUNTA:", pergunta)
    print("--------------------------------------------------------")
    print(tabela)
    print("\n")


# ============================================================
# 2) MULTIRRESPOSTA
# ============================================================
print("\n========================================================")
print("=================  MULTIRRESPOSTA  =====================")
print("========================================================\n")

for pergunta, tabela in t_multi.items():
    print("\n--------------------------------------------------------")
    print("PERGUNTA:", pergunta)
    print("--------------------------------------------------------")
    print(tabela)
    print("\n")


# ============================================================
# 3) MATRIZ TEXTO
# ============================================================
print("\n========================================================")
print("==================  MATRIZ TEXTO  =======================")
print("========================================================\n")

for pergunta, meios in t_matriz.items():
    print("\n--------------------------------------------------------")
    print("PERGUNTA:", pergunta)
    print("--------------------------------------------------------")

    for meio, tabela in meios.items():
        print(f"\n--- {meio} ---")
        print(tabela)
        print("\n")


# ============================================================
# 4) MATRIZ NOTA (0–10)
# ============================================================
print("\n========================================================")
print("===================  MATRIZ NOTA  =======================")
print("========================================================\n")

for pergunta, marcas in t_nota.items():
    print("\n--------------------------------------------------------")
    print("PERGUNTA:", pergunta)
    print("--------------------------------------------------------")

    for marca, tabela in marcas.items():
        print(f"\n--- {marca} ---")
        print(tabela)
        print("\n")

# ============================================================
# SALVAR RESULTADOS EM VARIÁVEL E EM ARQUIVO JSON
# ============================================================

resultado_json = gerar_json_todas_as_tabelas(t_simples, t_multi, t_matriz, t_nota)

# salvar localmente
with open("resultado_pesquisa.json", "w", encoding="utf-8") as f:
    f.write(resultado_json)

print("Arquivo JSON salvo como resultado_pesquisa.json")
# Out:
# ############################################################
# ######################  RESULTADOS  ########################
# ############################################################
#
#
#
# ========================================================
# ===============  PERGUNTAS SIMPLES  ====================
# ========================================================
#
#
# --------------------------------------------------------
# PERGUNTA: Em qual estado você vive? #est - Response
# --------------------------------------------------------
#                                            Frequência Absoluta  \
# Em qual estado você vive? #est - Response
# São Paulo                                                  167
# Rio de Janeiro                                              49
# Minas Gerais                                                26
# Bahia                                                       21
# Santa Catarina                                              17
# Pernambuco                                                  17
# Ceará                                                       16
# Rio Grande do Sul                                           12
# Paraná                                                       9
# Goiás                                                        8
# Piauí                                                        7
# Rio Grande do Norte                                          7
# Distrito Federal                                             7
# Pará                                                         6
# Espírito Santo                                               5
# Paraíba                                                      5
# Amazonas                                                     4
# Alagoas                                                      4
# Maranhão                                                     3
# Mato Grosso                                                  3
# Mato Grosso do Sul                                           2
# Acre                                                         2
# Sergipe                                                      1
# Roraima                                                      1
# Amapá                                                        1
#
#                                            Frequência Relativa (%)
# Em qual estado você vive? #est - Response
# São Paulo                                                     41.8
# Rio de Janeiro                                                12.2
# Minas Gerais                                                   6.5
# Bahia                                                          5.2
# Santa Catarina                                                 4.2
# Pernambuco                                                     4.2
# Ceará                                                          4.0
# Rio Grande do Sul                                              3.0
# Paraná                                                         2.2
# Goiás                                                          2.0
# Piauí                                                          1.8
# Rio Grande do Norte                                            1.8
# Distrito Federal                                               1.8
# Pará                                                           1.5
# Espírito Santo                                                 1.2
# Paraíba                                                        1.2
# Amazonas                                                       1.0
# Alagoas                                                        1.0
# Maranhão                                                       0.8
# Mato Grosso                                                    0.8
# Mato Grosso do Sul                                             0.5
# Acre                                                           0.5
# Sergipe                                                        0.2
# Roraima                                                        0.2
# Amapá                                                          0.2
#
#
#
# --------------------------------------------------------
# PERGUNTA: Qual é o seu gênero ? #gen - Response
# --------------------------------------------------------
#                                                     Frequência Absoluta  \
# Qual é o seu gênero ? #gen - Response
# Homem cisgênero (identifica-se com o gênero atr...                  249
# Mulher cisgênero (identifica-se com o gênero at...                  148
# Mulher trans (não se identifica com o gênero at...                    2
# Homem trans (não se identifica com o gênero atr...                    1
#
#                                                     Frequência Relativa (%)
# Qual é o seu gênero ? #gen - Response
# Homem cisgênero (identifica-se com o gênero atr...                     62.3
# Mulher cisgênero (identifica-se com o gênero at...                     37.0
# Mulher trans (não se identifica com o gênero at...                      0.5
# Homem trans (não se identifica com o gênero atr...                      0.2
#
#
#
# --------------------------------------------------------
# PERGUNTA: Quando você compra roupas, como costuma ESCOLHER A MARCA ? - Response
# --------------------------------------------------------
#                                                     Frequência Absoluta  \
# Quando você compra roupas, como costuma ESCOLHE...
# Tenho algumas marcas preferidas, mas GOSTO DE V...                  216
# Sempre compro DA MESMAS MARCAS que já conheço                        90
# Gosto de EXPERIMENTAR marcas novas COM FREQUÊNCIA                    51
# Não tenho preferência, compro pela peça ou pelo...                   43
#
#                                                     Frequência Relativa (%)
# Quando você compra roupas, como costuma ESCOLHE...
# Tenho algumas marcas preferidas, mas GOSTO DE V...                     54.0
# Sempre compro DA MESMAS MARCAS que já conheço                          22.5
# Gosto de EXPERIMENTAR marcas novas COM FREQUÊNCIA                      12.8
# Não tenho preferência, compro pela peça ou pelo...                     10.8
#
#
#
# --------------------------------------------------------
# PERGUNTA: Qual é a sua idade ? #idd - Response
# --------------------------------------------------------
#                                       Frequência Absoluta  \
# Qual é a sua idade ? #idd - Response
# 44 anos                                                18
# 40 anos                                                17
# 39 anos                                                16
# 28 anos                                                16
# 31 anos                                                16
# 42 anos                                                16
# 30 anos                                                16
# 34 anos                                                15
# 33 anos                                                14
# 36 anos                                                14
# 43 anos                                                14
# 38 anos                                                12
# 37 anos                                                12
# 41 anos                                                11
# 26 anos                                                11
# 35 anos                                                10
# 50 anos                                                10
# 32 anos                                                10
# 47 anos                                                10
# 45 anos                                                10
# 29 anos                                                 8
# 56 anos                                                 7
# 25 anos                                                 7
# 24 anos                                                 7
# 55 anos                                                 7
# 46 anos                                                 7
# 27 anos                                                 6
# 57 anos                                                 6
# 60 anos                                                 6
# 48 anos                                                 6
# 51 anos                                                 6
# 52 anos                                                 6
# 21 anos                                                 6
# 49 anos                                                 5
# 62 anos                                                 5
# 54 anos                                                 5
# Mais de 70 anos                                         4
# 53 anos                                                 4
# 22 anos                                                 3
# 65 anos                                                 3
# 64 anos                                                 3
# 20 anos                                                 3
# 69 anos                                                 2
# 70 anos                                                 2
# 19 anos                                                 1
# 58 anos                                                 1
# 18 anos                                                 1
# 61 anos                                                 1
# 63 anos                                                 1
# 23 anos                                                 1
# 68 anos                                                 1
# 59 anos                                                 1
#
#                                       Frequência Relativa (%)
# Qual é a sua idade ? #idd - Response
# 44 anos                                                   4.5
# 40 anos                                                   4.2
# 39 anos                                                   4.0
# 28 anos                                                   4.0
# 31 anos                                                   4.0
# 42 anos                                                   4.0
# 30 anos                                                   4.0
# 34 anos                                                   3.8
# 33 anos                                                   3.5
# 36 anos                                                   3.5
# 43 anos                                                   3.5
# 38 anos                                                   3.0
# 37 anos                                                   3.0
# 41 anos                                                   2.8
# 26 anos                                                   2.8
# 35 anos                                                   2.5
# 50 anos                                                   2.5
# 32 anos                                                   2.5
# 47 anos                                                   2.5
# 45 anos                                                   2.5
# 29 anos                                                   2.0
# 56 anos                                                   1.8
# 25 anos                                                   1.8
# 24 anos                                                   1.8
# 55 anos                                                   1.8
# 46 anos                                                   1.8
# 27 anos                                                   1.5
# 57 anos                                                   1.5
# 60 anos                                                   1.5
# 48 anos                                                   1.5
# 51 anos                                                   1.5
# 52 anos                                                   1.5
# 21 anos                                                   1.5
# 49 anos                                                   1.2
# 62 anos                                                   1.2
# 54 anos                                                   1.2
# Mais de 70 anos                                           1.0
# 53 anos                                                   1.0
# 22 anos                                                   0.8
# 65 anos                                                   0.8
# 64 anos                                                   0.8
# 20 anos                                                   0.8
# 69 anos                                                   0.5
# 70 anos                                                   0.5
# 19 anos                                                   0.2
# 58 anos                                                   0.2
# 18 anos                                                   0.2
# 61 anos                                                   0.2
# 63 anos                                                   0.2
# 23 anos                                                   0.2
# 68 anos                                                   0.2
# 59 anos                                                   0.2
#
#
#
# --------------------------------------------------------
# PERGUNTA: Qual dessas marcas você acha que mais COMBINA COM O SEU ESTILO de se vestir? - Response
# --------------------------------------------------------
#                                                     Frequência Absoluta  \
# Qual dessas marcas você acha que mais COMBINA C...
# Calvin Klein                                                         81
# Lacoste                                                              78
# Levi's                                                               50
# Polo Wear                                                            39
# Nenhuma das anteriores                                               28
# Tommy Hilfiger                                                       23
# Reserva                                                              23
# Brooksfield                                                          18
# John John                                                            13
# TNG                                                                  12
# Osklen                                                                8
# Diesel                                                                8
# Aramis                                                                8
# Ricardo Almeida                                                       5
# Richards                                                              4
# Sergio K                                                              2
#
#                                                     Frequência Relativa (%)
# Qual dessas marcas você acha que mais COMBINA C...
# Calvin Klein                                                           20.2
# Lacoste                                                                19.5
# Levi's                                                                 12.5
# Polo Wear                                                               9.8
# Nenhuma das anteriores                                                  7.0
# Tommy Hilfiger                                                          5.8
# Reserva                                                                 5.8
# Brooksfield                                                             4.5
# John John                                                               3.2
# TNG                                                                     3.0
# Osklen                                                                  2.0
# Diesel                                                                  2.0
# Aramis                                                                  2.0
# Ricardo Almeida                                                         1.2
# Richards                                                                1.0
# Sergio K                                                                0.5
#
#
#
# --------------------------------------------------------
# PERGUNTA: Osklen - Response
# --------------------------------------------------------
#                          Frequência Absoluta  Frequência Relativa (%)
# Osklen - Response
# NaN                                      225                     56.2
# Nada                                      25                      6.2
# Não lembro                                 3                      0.8
# Propaganda                                 3                      0.8
# Recomendação                               2                      0.5
# ...                                      ...                      ...
# Maravilhoso                                1                      0.2
# presente                                   1                      0.2
# Não vi ou ouvi nada.                       1                      0.2
# nada demais                                1                      0.2
# Não vi nada à respeito.                    1                      0.2
#
# [136 rows x 2 columns]
#
#
#
# --------------------------------------------------------
# PERGUNTA: Você está ATUALMENTE buscando ou planejando COMPRAR ROUPAS MASCULINAS ? #carac_Está_no_momento_de_compra? - Response
# --------------------------------------------------------
#                                                     Frequência Absoluta  \
# Você está ATUALMENTE buscando ou planejando COM...
# Sim, estou planejando comprar NESTE MÊS                             169
# Sim, estou planejando comprar NESTE ANO                              99
# Sim, estou planejando comprar NESTA SEMANA                           91
# Não estou planejando comprar                                         41
#
#                                                     Frequência Relativa (%)
# Você está ATUALMENTE buscando ou planejando COM...
# Sim, estou planejando comprar NESTE MÊS                                42.2
# Sim, estou planejando comprar NESTE ANO                                24.8
# Sim, estou planejando comprar NESTA SEMANA                             22.8
# Não estou planejando comprar                                           10.2
#
#
#
# --------------------------------------------------------
# PERGUNTA: Qual sua renda familiar mensal? (Renda familiar é a soma da renda de todas as pessoas que moram com você) #cls - Response
# --------------------------------------------------------
#                                                     Frequência Absoluta  \
# Qual sua renda familiar mensal? (Renda familiar...
# Entre R$ 8.513,00 e R$ 17.131,00 #B1                                105
# Entre R$ 2.772,00 e R$ 4.769,00 #C1                                  87
# Entre R$ 4.770,00 e R$ 8.512,00 #B2                                  77
# Entre R$ 1.521,00 e R$ 2.771,00 #C2                                  49
# Mais que R$ 23.318,00 #A1                                            31
# Entre R$ 17.132,00 e R$ 23.317,00 #A2                                30
# Entre R$ 958,00 e R$ 1.520,00 #D                                     16
# Até R$ 957,00 #E                                                      5
#
#                                                     Frequência Relativa (%)
# Qual sua renda familiar mensal? (Renda familiar...
# Entre R$ 8.513,00 e R$ 17.131,00 #B1                                   26.2
# Entre R$ 2.772,00 e R$ 4.769,00 #C1                                    21.8
# Entre R$ 4.770,00 e R$ 8.512,00 #B2                                    19.2
# Entre R$ 1.521,00 e R$ 2.771,00 #C2                                    12.2
# Mais que R$ 23.318,00 #A1                                               7.8
# Entre R$ 17.132,00 e R$ 23.317,00 #A2                                   7.5
# Entre R$ 958,00 e R$ 1.520,00 #D                                        4.0
# Até R$ 957,00 #E                                                        1.2
#
#
#
# --------------------------------------------------------
# PERGUNTA: Em qual cidade você mora? #cid - Response
# --------------------------------------------------------
#                                            Frequência Absoluta  \
# Em qual cidade você mora? #cid - Response
# São Paulo (SP)                                              89
# Rio de Janeiro (RJ)                                         32
# Belo Horizonte (MG)                                         17
# Fortaleza (CE)                                              16
# Salvador (BA)                                               14
# ...                                                        ...
# Uberlândia (MG)                                              1
# Vila Velha (ES)                                              1
# Arapiraca                                                    1
# São Thomé das letras                                         1
# Balneario Camboriu                                           1
#
#                                            Frequência Relativa (%)
# Em qual cidade você mora? #cid - Response
# São Paulo (SP)                                                22.2
# Rio de Janeiro (RJ)                                            8.0
# Belo Horizonte (MG)                                            4.2
# Fortaleza (CE)                                                 4.0
# Salvador (BA)                                                  3.5
# ...                                                            ...
# Uberlândia (MG)                                                0.2
# Vila Velha (ES)                                                0.2
# Arapiraca                                                      0.2
# São Thomé das letras                                           0.2
# Balneario Camboriu                                             0.2
#
# [110 rows x 2 columns]
#
#
#
# --------------------------------------------------------
# PERGUNTA: Como você descreveria SEU ESTILO de vestir hoje? - Response
# --------------------------------------------------------
#                                                     Frequência Absoluta  \
# Como você descreveria SEU ESTILO de vestir hoje...
# Tenho um estilo principal, mas GOSTO DE VARIAR ...                  196
# Tenho um estilo bem definido e quase SEMPRE SIG...                  116
# Meu estilo MUDA BASTANTE conforme o dia ou ocasião                   60
# Não tenho um estilo próprio / Não penso sobre isso                   28
#
#                                                     Frequência Relativa (%)
# Como você descreveria SEU ESTILO de vestir hoje...
# Tenho um estilo principal, mas GOSTO DE VARIAR ...                     49.0
# Tenho um estilo bem definido e quase SEMPRE SIG...                     29.0
# Meu estilo MUDA BASTANTE conforme o dia ou ocasião                     15.0
# Não tenho um estilo próprio / Não penso sobre isso                      7.0
#
#
#
# --------------------------------------------------------
# PERGUNTA: Com que frequência você COMPRA ROUPAS MASCULINAS ? #carac_Frequência_de_Compra
# --------------------------------------------------------
#                                                     Frequência Absoluta  \
# Com que frequência você COMPRA ROUPAS MASCULINA...
# Com frequência                                                      158
# Às vezes                                                            145
# Sempre                                                               55
# Raramente                                                            36
# Nunca                                                                 6
#
#                                                     Frequência Relativa (%)
# Com que frequência você COMPRA ROUPAS MASCULINA...
# Com frequência                                                         39.5
# Às vezes                                                               36.2
# Sempre                                                                 13.8
# Raramente                                                               9.0
# Nunca                                                                   1.5
#
#
#
# --------------------------------------------------------
# PERGUNTA: Qual é a sua escolaridade ? #esc - Response
# --------------------------------------------------------
#                                              Frequência Absoluta  \
# Qual é a sua escolaridade ? #esc - Response
# Ensino superior (completo) #suc                              178
# Ensino médio (completo) #mec                                  81
# Pós-graduação (completo) #emc                                 50
# Ensino superior (incompleto) #sui                             35
# Mestrado (completo) #mes                                      29
# Ensino fundamental (completo) #fuc                             7
# Pós-graduação (incompleto) #emi                                7
# Doutorado (incompleto) #doc                                    6
# Mestrado (incompleto) #mes                                     4
# Ensino médio (incompleto) #mei                                 3
#
#                                              Frequência Relativa (%)
# Qual é a sua escolaridade ? #esc - Response
# Ensino superior (completo) #suc                                 44.5
# Ensino médio (completo) #mec                                    20.2
# Pós-graduação (completo) #emc                                   12.5
# Ensino superior (incompleto) #sui                                8.8
# Mestrado (completo) #mes                                         7.2
# Ensino fundamental (completo) #fuc                               1.8
# Pós-graduação (incompleto) #emi                                  1.8
# Doutorado (incompleto) #doc                                      1.5
# Mestrado (incompleto) #mes                                       1.0
# Ensino médio (incompleto) #mei                                   0.8
#
#
#
# --------------------------------------------------------
# PERGUNTA: Considerando os times nacionais de FUTEBOL MASCULINO , para QUAL TIME VOCÊ TORCE ? #carac_Time_de_Futebol - Response
# --------------------------------------------------------
#                                                     Frequência Absoluta  \
# Considerando os times nacionais de FUTEBOL MASC...
# Flamengo                                                             94
# São Paulo                                                            56
# Corinthians                                                          55
# Não torço para nenhum time de futebol                                38
# Palmeiras                                                            29
# Santos                                                               16
# Cruzeiro                                                             15
# Vasco da Gama                                                        11
# Fluminense                                                           10
# Atlético Mineiro                                                      9
# Grêmio                                                                9
# Bahia                                                                 8
# Botafogo                                                              8
# Sport                                                                 7
# Internacional                                                         7
# Fortaleza                                                             6
# Ceará                                                                 5
# América Mineiro                                                       3
# Outro(s)                                                              3
# Santa Cruz                                                            2
# Atlético Goianiense                                                   2
# Criciúma                                                              2
# ABC                                                                   2
# Goiás                                                                 1
# Athletico Paranaense                                                  1
# Vitória                                                               1
#
#                                                     Frequência Relativa (%)
# Considerando os times nacionais de FUTEBOL MASC...
# Flamengo                                                               23.5
# São Paulo                                                              14.0
# Corinthians                                                            13.8
# Não torço para nenhum time de futebol                                   9.5
# Palmeiras                                                               7.2
# Santos                                                                  4.0
# Cruzeiro                                                                3.8
# Vasco da Gama                                                           2.8
# Fluminense                                                              2.5
# Atlético Mineiro                                                        2.2
# Grêmio                                                                  2.2
# Bahia                                                                   2.0
# Botafogo                                                                2.0
# Sport                                                                   1.8
# Internacional                                                           1.8
# Fortaleza                                                               1.5
# Ceará                                                                   1.2
# América Mineiro                                                         0.8
# Outro(s)                                                                0.8
# Santa Cruz                                                              0.5
# Atlético Goianiense                                                     0.5
# Criciúma                                                                0.5
# ABC                                                                     0.5
# Goiás                                                                   0.2
# Athletico Paranaense                                                    0.2
# Vitória                                                                 0.2
#
#
#
# --------------------------------------------------------
# PERGUNTA: Lacoste - Response
# --------------------------------------------------------
#                                                     Frequência Absoluta  \
# Lacoste - Response
# NaN                                                                  40
# Nada                                                                 27
# Propaganda                                                           13
# Qualidade                                                             8
# Não lembro                                                            6
# ...                                                                 ...
# É uma marca popular entre os homens mas as veze...                    1
# Malha boa                                                             1
# que são boas as roupas                                                1
# Recomendação de que a marca é boa                                     1
# Vi pessoas usando as peças nas redes sociais                          1
#
#                                                     Frequência Relativa (%)
# Lacoste - Response
# NaN                                                                    10.0
# Nada                                                                    6.8
# Propaganda                                                              3.2
# Qualidade                                                               2.0
# Não lembro                                                              1.5
# ...                                                                     ...
# É uma marca popular entre os homens mas as veze...                      0.2
# Malha boa                                                               0.2
# que são boas as roupas                                                  0.2
# Recomendação de que a marca é boa                                       0.2
# Vi pessoas usando as peças nas redes sociais                            0.2
#
# [289 rows x 2 columns]
#
#
#
# --------------------------------------------------------
# PERGUNTA: Reserva - Response
# --------------------------------------------------------
#                                               Frequência Absoluta  \
# Reserva - Response
# NaN                                                           210
# Nada                                                           21
# Propaganda                                                      6
# nada                                                            4
# Qualidade                                                       3
# ...                                                           ...
# Ótimo                                                           1
# email com cupom                                                 1
# Não vi ou ouvi nada.                                            1
# nada demais                                                     1
# Fui recomendado sobre essa marca por amigos.                    1
#
#                                               Frequência Relativa (%)
# Reserva - Response
# NaN                                                              52.5
# Nada                                                              5.2
# Propaganda                                                        1.5
# nada                                                              1.0
# Qualidade                                                         0.8
# ...                                                               ...
# Ótimo                                                             0.2
# email com cupom                                                   0.2
# Não vi ou ouvi nada.                                              0.2
# nada demais                                                       0.2
# Fui recomendado sobre essa marca por amigos.                      0.2
#
# [157 rows x 2 columns]
#
#
#
# ========================================================
# =================  MULTIRRESPOSTA  =====================
# ========================================================
#
#
# --------------------------------------------------------
# PERGUNTA: Das marcas abaixo, quais você se lembra de ter visto propaganda recentemente? Selecione todas as que lembrar. #Carac_Recall_de_Propaganda
# --------------------------------------------------------
#                                                     Frequência Absoluta  \
# Richards                                                             14
# John John                                                            39
# Não me lembro de ter visto propaganda de nenhum...                  144
# Osklen                                                               36
# Lacoste                                                             142
# Brooksfield                                                          23
# TNG                                                                  19
# Tommy Hilfiger                                                       44
# Polo Wear                                                            61
# Diesel                                                               28
# Ricardo Almeida                                                      12
# Levi's                                                               69
# Calvin Klein                                                        135
# Aramis                                                               26
# Reserva                                                              55
# Sergio K                                                              6
#
#                                                     Frequência Relativa (%)
# Richards                                                                3.5
# John John                                                               9.8
# Não me lembro de ter visto propaganda de nenhum...                     36.0
# Osklen                                                                  9.0
# Lacoste                                                                35.5
# Brooksfield                                                             5.8
# TNG                                                                     4.8
# Tommy Hilfiger                                                         11.0
# Polo Wear                                                              15.2
# Diesel                                                                  7.0
# Ricardo Almeida                                                         3.0
# Levi's                                                                 17.2
# Calvin Klein                                                           33.8
# Aramis                                                                  6.5
# Reserva                                                                13.8
# Sergio K                                                                1.5
#
#
#
# --------------------------------------------------------
# PERGUNTA: Você PRESENTEOU, NOS ÚLTIMOS MESES , alguém próximo (amigo ou familiar) com alguma das marcas abaixo? Quais? Selecione todas as marcas que tiver dado como presente. #carac_Presenteou_recentemente_com_as_marcas
# --------------------------------------------------------
#                                            Frequência Absoluta  \
# TNG                                                         23
# Tommy Hilfiger                                              46
# Sergio K                                                     9
# Calvin Klein                                               115
# Osklen                                                      24
# Polo Wear                                                   72
# Ricardo Almeida                                             12
# Aramis                                                      26
# Levi's                                                      69
# John John                                                   42
# Brooksfield                                                 24
# Reserva                                                     54
# Não dei de presente nenhuma dessas marcas                  117
# Richards                                                    12
# Lacoste                                                    117
# Diesel                                                      27
#
#                                            Frequência Relativa (%)
# TNG                                                            5.8
# Tommy Hilfiger                                                11.5
# Sergio K                                                       2.2
# Calvin Klein                                                  28.7
# Osklen                                                         6.0
# Polo Wear                                                     18.0
# Ricardo Almeida                                                3.0
# Aramis                                                         6.5
# Levi's                                                        17.2
# John John                                                     10.5
# Brooksfield                                                    6.0
# Reserva                                                       13.5
# Não dei de presente nenhuma dessas marcas                     29.2
# Richards                                                       3.0
# Lacoste                                                       29.2
# Diesel                                                         6.8
#
#
#
# ========================================================
# ==================  MATRIZ TEXTO  =======================
# ========================================================
#
#
# --------------------------------------------------------
# PERGUNTA: Com que frequência você utiliza e CONSOME CONTEÚDOS nos meios abaixo?
# --------------------------------------------------------
#
# --- Facebook ---
#                                                     Frequência Absoluta  \
# Com que frequência você utiliza e CONSOME CONTE...
# Todos os dias                                                       148
# Mais de uma vez por dia                                             115
# Uma vez por semana                                                   46
# Nunca                                                                41
# Uma vez por mês                                                      26
# Menos de uma vez por mês                                             24
#
#                                                     Frequência Relativa (%)
# Com que frequência você utiliza e CONSOME CONTE...
# Todos os dias                                                          37.0
# Mais de uma vez por dia                                                28.7
# Uma vez por semana                                                     11.5
# Nunca                                                                  10.2
# Uma vez por mês                                                         6.5
# Menos de uma vez por mês                                                6.0
#
#
#
# --- Revistas ou Jornais impressos ---
#                                                     Frequência Absoluta  \
# Com que frequência você utiliza e CONSOME CONTE...
# Nunca                                                               155
# Menos de uma vez por mês                                             72
# Uma vez por semana                                                   68
# Todos os dias                                                        52
# Uma vez por mês                                                      29
# Mais de uma vez por dia                                              24
#
#                                                     Frequência Relativa (%)
# Com que frequência você utiliza e CONSOME CONTE...
# Nunca                                                                  38.8
# Menos de uma vez por mês                                               18.0
# Uma vez por semana                                                     17.0
# Todos os dias                                                          13.0
# Uma vez por mês                                                         7.2
# Mais de uma vez por dia                                                 6.0
#
#
#
# --- Televisão (canais pagos) ---
#                                                     Frequência Absoluta  \
# Com que frequência você utiliza e CONSOME CONTE...
# Todos os dias                                                       171
# Mais de uma vez por dia                                              81
# Uma vez por semana                                                   58
# Nunca                                                                58
# Menos de uma vez por mês                                             19
# Uma vez por mês                                                      13
#
#                                                     Frequência Relativa (%)
# Com que frequência você utiliza e CONSOME CONTE...
# Todos os dias                                                          42.8
# Mais de uma vez por dia                                                20.2
# Uma vez por semana                                                     14.5
# Nunca                                                                  14.5
# Menos de uma vez por mês                                                4.8
# Uma vez por mês                                                         3.2
#
#
#
# --- Cinema ---
#                                                     Frequência Absoluta  \
# Com que frequência você utiliza e CONSOME CONTE...
# Uma vez por mês                                                     158
# Menos de uma vez por mês                                            115
# Uma vez por semana                                                   50
# Nunca                                                                43
# Mais de uma vez por dia                                              19
# Todos os dias                                                        15
#
#                                                     Frequência Relativa (%)
# Com que frequência você utiliza e CONSOME CONTE...
# Uma vez por mês                                                        39.5
# Menos de uma vez por mês                                               28.7
# Uma vez por semana                                                     12.5
# Nunca                                                                  10.8
# Mais de uma vez por dia                                                 4.8
# Todos os dias                                                           3.8
#
#
#
# --- X (Twitter) ---
#                                                     Frequência Absoluta  \
# Com que frequência você utiliza e CONSOME CONTE...
# Nunca                                                               139
# Todos os dias                                                        82
# Uma vez por semana                                                   64
# Mais de uma vez por dia                                              56
# Menos de uma vez por mês                                             34
# Uma vez por mês                                                      25
#
#                                                     Frequência Relativa (%)
# Com que frequência você utiliza e CONSOME CONTE...
# Nunca                                                                  34.8
# Todos os dias                                                          20.5
# Uma vez por semana                                                     16.0
# Mais de uma vez por dia                                                14.0
# Menos de uma vez por mês                                                8.5
# Uma vez por mês                                                         6.2
#
#
#
# --- Instagram ---
#                                                     Frequência Absoluta  \
# Com que frequência você utiliza e CONSOME CONTE...
# Mais de uma vez por dia                                             186
# Todos os dias                                                       132
# Uma vez por semana                                                   35
# Nunca                                                                23
# Uma vez por mês                                                      13
# ...
# 7.0                                                                  23
# 8.0                                                                  24
# 9.0                                                                  13
# 10.0                                                                 45
#
#                                                     Frequência Relativa (%)
# O quanto você gostaria de PRESENTEAR ALGUÉM pró...
# 0.0                                                                     1.5
# 2.0                                                                     2.3
# 3.0                                                                     1.5
# 4.0                                                                     2.3
# 5.0                                                                     9.2
# 6.0                                                                     2.3
# 7.0                                                                    17.7
# 8.0                                                                    18.5
# 9.0                                                                    10.0
# 10.0                                                                   34.6
#
#
#
# --- Richards ---
#                                                     Frequência Absoluta  \
# O quanto você gostaria de PRESENTEAR ALGUÉM pró...
# 0.0                                                                   2
# 2.0                                                                   1
# 3.0                                                                   5
# 5.0                                                                  13
# 6.0                                                                   9
# 7.0                                                                   6
# 8.0                                                                  20
# 9.0                                                                  14
# 10.0                                                                 29
#
#                                                     Frequência Relativa (%)
# O quanto você gostaria de PRESENTEAR ALGUÉM pró...
# 0.0                                                                     2.0
# 2.0                                                                     1.0
# 3.0                                                                     5.1
# 5.0                                                                    13.1
# 6.0                                                                     9.1
# 7.0                                                                     6.1
# 8.0                                                                    20.2
# 9.0                                                                    14.1
# 10.0                                                                   29.3
#
#
#
# --- Diesel ---
#                                                     Frequência Absoluta  \
# O quanto você gostaria de PRESENTEAR ALGUÉM pró...
# 0.0                                                                   6
# 1.0                                                                   1
# 2.0                                                                   2
# 3.0                                                                   7
# 4.0                                                                   3
# 5.0                                                                  20
# 6.0                                                                  12
# 7.0                                                                  23
# 8.0                                                                  31
# 9.0                                                                  23
# 10.0                                                                 73
#
#                                                     Frequência Relativa (%)
# O quanto você gostaria de PRESENTEAR ALGUÉM pró...
# 0.0                                                                     3.0
# 1.0                                                                     0.5
# 2.0                                                                     1.0
# 3.0                                                                     3.5
# 4.0                                                                     1.5
# 5.0                                                                    10.0
# 6.0                                                                     6.0
# 7.0                                                                    11.4
# 8.0                                                                    15.4
# 9.0                                                                    11.4
# 10.0                                                                   36.3
#
#
#
# --- Ricardo Almeida ---
#                                                     Frequência Absoluta  \
# O quanto você gostaria de PRESENTEAR ALGUÉM pró...
# 0.0                                                                   2
# 1.0                                                                   2
# 2.0                                                                   1
# 3.0                                                                   4
# 5.0                                                                   8
# 6.0                                                                   7
# 7.0                                                                   5
# 8.0                                                                  15
# 9.0                                                                   9
# 10.0                                                                 29
#
#                                                     Frequência Relativa (%)
# O quanto você gostaria de PRESENTEAR ALGUÉM pró...
# 0.0                                                                     2.4
# 1.0                                                                     2.4
# 2.0                                                                     1.2
# 3.0                                                                     4.9
# 5.0                                                                     9.8
# 6.0                                                                     8.5
# 7.0                                                                     6.1
# 8.0                                                                    18.3
# 9.0                                                                    11.0
# 10.0                                                                   35.4
#
#
#
# --- Polo Wear ---
#                                                     Frequência Absoluta  \
# O quanto você gostaria de PRESENTEAR ALGUÉM pró...
# 0.0                                                                   6
# 1.0                                                                   1
# 2.0                                                                   2
# 3.0                                                                   1
# 4.0                                                                   2
# 5.0                                                                  18
# 6.0                                                                  14
# 7.0                                                                  23
# 8.0                                                                  38
# 9.0                                                                  28
# 10.0                                                                104
#
#                                                     Frequência Relativa (%)
# O quanto você gostaria de PRESENTEAR ALGUÉM pró...
# 0.0                                                                     2.5
# 1.0                                                                     0.4
# 2.0                                                                     0.8
# 3.0                                                                     0.4
# 4.0                                                                     0.8
# 5.0                                                                     7.6
# 6.0                                                                     5.9
# 7.0                                                                     9.7
# 8.0                                                                    16.0
# 9.0                                                                    11.8
# 10.0                                                                   43.9
#
#
#
# --- Calvin Klein ---
#                                                     Frequência Absoluta  \
# O quanto você gostaria de PRESENTEAR ALGUÉM pró...
# 0.0                                                                   7
# 2.0                                                                   4
# 3.0                                                                   5
# 4.0                                                                   4
# 5.0                                                                  28
# 6.0                                                                  13
# 7.0                                                                  31
# 8.0                                                                  54
# 9.0                                                                  51
# 10.0                                                                162
#
#                                                     Frequência Relativa (%)
# O quanto você gostaria de PRESENTEAR ALGUÉM pró...
# 0.0                                                                     1.9
# 2.0                                                                     1.1
# 3.0                                                                     1.4
# 4.0                                                                     1.1
# 5.0                                                                     7.8
# 6.0                                                                     3.6
# 7.0                                                                     8.6
# 8.0                                                                    15.0
# 9.0                                                                    14.2
# 10.0                                                                   45.1
#
#
#
# --- Lacoste ---
#                                                     Frequência Absoluta  \
# O quanto você gostaria de PRESENTEAR ALGUÉM pró...
# 0.0                                                                   7
# 1.0                                                                   1
# 2.0                                                                   9
# 3.0                                                                   5
# 4.0                                                                   5
# 5.0                                                                  24
# 6.0                                                                  19
# 7.0                                                                  29
# 8.0                                                                  50
# 9.0                                                                  48
# 10.0                                                                163
#
#                                                     Frequência Relativa (%)
# O quanto você gostaria de PRESENTEAR ALGUÉM pró...
# 0.0                                                                     1.9
# 1.0                                                                     0.3
# 2.0                                                                     2.5
# 3.0                                                                     1.4
# 4.0                                                                     1.4
# 5.0                                                                     6.7
# 6.0                                                                     5.3
# 7.0                                                                     8.1
# 8.0                                                                    13.9
# 9.0                                                                    13.3
# 10.0                                                                   45.3
#
#
#
# --- John John ---
#                                                     Frequência Absoluta  \
# O quanto você gostaria de PRESENTEAR ALGUÉM pró...
# 0.0                                                                   3
# 1.0                                                                   1
# 2.0                                                                   1
# 3.0                                                                   4
# 4.0                                                                   6
# 5.0                                                                  22
# 6.0                                                                  16
# 7.0                                                                  22
# 8.0                                                                  29
# 9.0                                                                  28
# 10.0                                                                 75
#
#                                                     Frequência Relativa (%)
# O quanto você gostaria de PRESENTEAR ALGUÉM pró...
# 0.0                                                                     1.4
# 1.0                                                                     0.5
# 2.0                                                                     0.5
# 3.0                                                                     1.9
# 4.0                                                                     2.9
# 5.0                                                                    10.6
# 6.0                                                                     7.7
# 7.0                                                                    10.6
# 8.0                                                                    14.0
# 9.0                                                                    13.5
# 10.0                                                                   36.2
#
#
#
# --------------------------------------------------------
# PERGUNTA: respondent_id
# --------------------------------------------------------
#
# --- respondent_id ---
#                                Frequência Absoluta  Frequência Relativa (%)
# respondent_id - respondent_id
# 114879820679                                     1                      0.2
# 114879821637                                     1                      0.2
# 114879822663                                     1                      0.2
# 114879823103                                     1                      0.2
# 114879823597                                     1                      0.2
# ...                                            ...                      ...
# 118888890526                                     1                      0.2
# 118888891032                                     1                      0.2
# 118888891878                                     1                      0.2
# 118888893006                                     1                      0.2
# 118888896063                                     1                      0.2
#
# [400 rows x 2 columns]
#
#
# Arquivo JSON salvo como resultado_pesquisa.json
